# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("bank-full.csv",sep=";",usecols=['age','job','education','balance','housing','loan','y'])
data.head()
# Out:
#    age           job  education  balance housing loan   y
# 0   58    management   tertiary     2143     yes   no  no
# 1   44    technician  secondary       29     yes   no  no
# 2   33  entrepreneur  secondary        2     yes  yes  no
# 3   47   blue-collar    unknown     1506     yes   no  no
# 4   33       unknown    unknown        1      no   no  no

# %%
data['job'].unique()
# Out:
# array(['management', 'technician', 'entrepreneur', 'blue-collar',
#        'unknown', 'retired', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   education  45211 non-null  object
#  3   balance    45211 non-null  int64
#  4   housing    45211 non-null  object
#  5   loan       45211 non-null  object
#  6   y          45211 non-null  object
# dtypes: int64(2), object(5)
# memory usage: 2.4+ MB

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(data.iloc[:,:-1],
                                                 data.iloc[:,-1:],
                                                 test_size=.2,
                                                 random_state=42)

# %%
data['education'].unique()
# Out:
# array(['tertiary', 'secondary', 'unknown', 'primary'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.compose import ColumnTransformer

# %%
trf1 = ColumnTransformer([
    ('oe_education',OrdinalEncoder(categories=[['unknown','primary','secondary','tertiary']]),[2]),
    ('ohe_cols',OneHotEncoder(dtype='int'),[1,4,5])
],remainder='passthrough')

# %%
lr = LogisticRegression()

# %%
from sklearn.pipeline import Pipeline

pipe = Pipeline([
    ('trf1',trf1),
    ('lr',lr)
])

# %%
pipe.named_steps
# Out:
# {'trf1': ColumnTransformer(remainder='passthrough',
#                    transformers=[('oe_education',
#                                   OrdinalEncoder(categories=[['unknown',
#                                                               'primary',
#                                                               'secondary',
#                                                               'tertiary']]),
#                                   [2]),
#                                  ('ohe_cols', OneHotEncoder(dtype='int'),
#                                   [1, 4, 5])]),
#  'lr': LogisticRegression()}

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('trf1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('oe_education',
#                                                   OrdinalEncoder(categories=[['unknown',
#                                                                               'primary',
#                                                                               'secondary',
#                                                                               'tertiary']]),
#                                                   [2]),
#                                                  ('ohe_cols',
#                                                   OneHotEncoder(dtype='int'),
#                                                   [1, 4, 5])])),
#                 ('lr', LogisticRegression())])

# %%
y_pred = pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test,y_pred)
# Out:
# 0.8791330310737587
